# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
x = np.linspace(start=1, stop=10, num = 1000)
x1 = np.linspace(start=0, stop=10)
plt.plot(x, x-1)
plt.plot(x1, 2**(x1-1))
plt.plot(x1, np.log(x1))
# Out:
# /tmp/ipykernel_61977/2673392895.py:5: RuntimeWarning: divide by zero encountered in log
#   plt.plot(x1, np.log(x1))
